# %%
import pandas as pd

# %%
df = pd.read_csv('ric_active_calls-20230209-20230611.csv')

# %%
df2 = pd.read_csv('ric_active_calls.csv')

# %%
df = pd.concat([df,df2]).reset_index(drop=True)

# %%
df
#df.loc[df['Agency']=='RPD'].groupby('Unit').count()
# Out:
#            Time Received Agency Dispatch Area   Unit  \
# 0       02/09/2023 20:47    RPD    Precinct 4  413B2
# 1       02/10/2023 08:22    RPD    Precinct 4    751
# 2       02/10/2023 08:22    RPD    Precinct 4    752
# 3       02/10/2023 08:22    RPD    Precinct 4    761
# 4       02/10/2023 08:22    RPD    Precinct 4    762
# ...                  ...    ...           ...    ...
# 213711  10/27/2023 10:35    RPD    Precinct 2  212A2
# 213712  10/27/2023 10:38    RPD    Precinct 3    468
# 213713  10/27/2023 10:34    RPD    Precinct 1  112C1
# 213714  10/27/2023 10:44    RPD    Precinct 3  311C3
# 213715  10/27/2023 10:45    RPD    Precinct 3  313B2
#
#                                             Call Type  \
# 0            MENTAL SUBJECT , MENTAL SUBJECT EMERGENT
# 1                           PERSON DOWN , INVESTIGATE
# 2                           PERSON DOWN , INVESTIGATE
# 3                           PERSON DOWN , INVESTIGATE
# ...
